# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
db_url = os.environ['DB_HEROKU']

# %%
#from base import Base
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# %%
print(db_url)
# Out:
# postgres://hiikokjjrwmqpg:ff6d83e0795990ffb048d526caf295eaad7a45476691991f989be513d4e3a6bb@ec2-54-83-60-13.compute-1.amazonaws.com:5432/d617hc9tos6o76

# %%
import sys
sys.path.append("/Users/szagar/ZTS/Dropbox/Business/ats/Code/Model/v2")

from market import Market
from strategy import Strategy
#from stress_test import StressTest
from market_internal import MarketInternal
from base import Base,Session

# %%
engine = create_engine(db_url)
Base.metadata.bind = engine

# %%
Base.metadata.create_all(bind=engine)

# %%
db = Session()

# %%
def marketsData():
    return db.query(Market.symbol,
                    Market.ts_symbol,
                    Market.name,
                    Market.default_session).all()

# %%
def getSecInfoBySymbol(sym):
    return db.query(Market).filter(Market.ts_symbol==sym).all()

# %%
import pandas as pd
df=pd.DataFrame(marketsData())
df
# Out:
#    symbol ts_symbol                  name  default_session
# 0     @ES     @ES.D         Emini S&P 500              9.0
# 1     @YM     @YM.D          Emini Dow 30              9.0
# 2     @NQ     @NQ.D          Emini NASDAQ              9.0
# 3    @RTY    @RTY.D         Emini Russell              9.0
# 4    @EMD    @EMD.D      Emini MidCap 400              9.0
# 5     @CL       @CL             Crude Oil              7.0
# 6     @NG       @NG           Natural Gas              7.0
# 7     @RB       @RB         RBOB Gasoline              7.0
# 8     @HO       @HO           Heating Oil              7.0
# 9     @GC       @GC                  Gold             10.0
# 10    @SI       @SI                Silver              3.0
# 11    @HG       @HG                Copper              2.0
# 12     @C        @C                  Corn              5.0
# 13     @S        @S              Soybeans              5.0
# 14    @ZW       @ZW                 Wheat              5.0
# ...

# %%
r=marketsData()

# %%
r2=pd.DataFrame(getSecInfoBySymbol('@ES.D'))
r2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/anaconda3/envs/sqlstuff/lib/python3.7/site-packages/sqlalchemy/ext/declarative/clsregistry.py in __call__(self)
#     280         try:
# --> 281             x = eval(self.arg, globals(), self._dict)
#     282
#
# ~/anaconda3/envs/sqlstuff/lib/python3.7/site-packages/sqlalchemy/ext/declarative/clsregistry.py in <module>()
#
# NameError: name 'OosTest' is not defined
#
# During handling of the above exception, another exception occurred:
#
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-15-9e21fc7134ca> in <module>()
# ----> 1 r2=pd.DataFrame(getSecInfoBySymbol('@ES.D'))
#       2 r2
#
# <ipython-input-12-c5cb5668689a> in getSecInfoBySymbol(sym)
#       1 def getSecInfoBySymbol(sym):
# ----> 2     return db.query(Market).filter(Market.ts_symbol==sym).all()
#
# ...

# %%
print(*r2, sep='/n')
# Out:
# <Market(name='Emini S&P 500', symbol='@ES.D', group='Indices')>

# %%
print('\n'.join(str(p) for p in r2[0]))
# Out:
# <Market(name='Emini S&P 500', symbol='@ES.D', group='Indices')>

# %%
r2
# Out:
#                                                    0
# 0  <Market(name='Emini S&P 500', symbol='@ES.D', ...

# %%
r2[0]
# Out:
# 0    <Market(name='Emini S&P 500', symbol='@ES.D', ...
# Name: 0, dtype: object

# %%
float(r2[0].comm_entry_dol)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-274d009cfbd1> in <module>()
# ----> 1 float(r2[0].comm_entry_dol)
#
# ~/anaconda3/envs/sqlstuff/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'comm_entry_dol'

# %%
a=float(comm)+8.5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-93247332377d> in <module>()
# ----> 1 a=float(comm)+8.5
#
# NameError: name 'comm' is not defined

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-3f786850e387> in <module>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
df
# Out:
#    symbol ts_symbol              name  default_session
# 0     @ES     @ES.D     Emini S&P 500                9
# 1     @YM     @YM.D      Emini Dow 30                9
# 2     @NQ     @NQ.D      Emini NASDAQ                9
# 3    @RTY    @RTY.D     Emini Russell                9
# 4    @EMD    @EMD.D  Emini MidCap 400                9
# 5     @CL       @CL         Crude Oil                7
# 6     @NG       @NG       Natural Gas                7
# 7     @RB       @RB     RBOB Gasoline                7
# 8     @HO       @HO       Heating Oil                7
# 9     @GC       @GC              Gold               10
# 10    @SI       @SI            Silver                3
# 11    @HG       @HG            Copper                2
# 12    @ZC       @ZC              Corn                5
# 13     @S        @S          Soybeans                5
# 14    @ZW       @ZW             Wheat                5
# 15    @LC       @LC       Live Cattle                6
# ...
